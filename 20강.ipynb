# %%
import pandas as pd

# %%
titanic=pd.read_csv("data/titanic.csv")
titanic["age"]=titanic["age"].replace(["?"],[None]).astype(float)
titanic["fare"]=titanic["fare"].replace(["?"],[None]).astype(float)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["age"]=titanic["age"].replace(["?"],[None]).astype(float)
titanic["fare"]=titanic["fare"].replace(["?"],[None]).astype(float)

# %%
titanic["name"].str.upper()
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
lower_name=titanic["name"].str.lower()

# %%
titanic["lower_name"]=titanic["name"].str.lower()

# %%
titanic["cabin"][0][0]
# Out:
# 'B'

# %%
titanic["deck"]=titanic["cabin"].str[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.groupby("deck")["survived"].mean().sort_values(ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='deck'>

# %%
titanic[titanic["deck"]=="T"]["survived"].count()
# Out:
# 1

# %%
ufos=pd.read_csv("data/nuforc_reports.csv")

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos["duration"]=ufos["duration"].str[:]

# %%
ufos["duration"].str.replace("seconds","s")
# Out:
# 0              5 s
# 1            3-5 s
# 2              NaN
# 3             10 s
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121         20 s
# 88122         20 s
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds|minutes","")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_6832\2012289400.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ufos["duration"].str.replace("seconds|minutes","")
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds","").str.replace("minutes","")

# %%
ufos["duration"].str.replace("seconds|minutes","",regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
def z(a):
    return a.group()[0]
ufos["duration"].str.replace("seconds|minutes|hours",z)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_11188\3615093370.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   ufos["duration"].str.replace("seconds|minutes|hours",z)
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds","s").str.replace("minutes","m")
# Out:
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.contains("seconds")
# Out:
# 0         True
# 1         True
# 2          NaN
# 3         True
# 4        False
#          ...
# 88120    False
# 88121     True
# 88122     True
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
def z(a):
    return a*365
z(titanic["age"])
# Out:
# 0       10585.0000
# 1         334.5955
# 2         730.0000
# 3       10950.0000
# 4        9125.0000
#            ...
# 1304     5292.5000
# 1305           NaN
# 1306     9672.5000
# 1307     9855.0000
# 1308    10585.0000
# Name: age, Length: 1309, dtype: float64

# %%
titanic["age"].apply(z)
# Out:
# 0       10585.0000
# 1         334.5955
# 2         730.0000
# 3       10950.0000
# 4        9125.0000
#            ...
# 1304     5292.5000
# 1305           NaN
# 1306     9672.5000
# 1307     9855.0000
# 1308    10585.0000
# Name: age, Length: 1309, dtype: float64

# %%
def z(a):
    if a <2 :
        return "infant"
    elif a<12:
        return "child"
    elif a<18:
        return "teen"
    elif a<50:
        return "adult"
    else:
        return "senior"

# %%
titanic["age"].apply(z)
# Out:
# 0        adult
# 1       infant
# 2        child
# 3        adult
# 4        adult
#          ...
# 1304      teen
# 1305    senior
# 1306     adult
# 1307     adult
# 1308     adult
# Name: age, Length: 1309, dtype: object

# %%
titanic["age_group"].value_counts("survived")
# Out:
# adult     0.597403
# senior    0.284950
# child     0.052712
# teen      0.048128
# infant    0.016807
# Name: age_group, dtype: float64

# %%
titanic["age_group"]=titanic["age"].apply(z)

# %%
titanic.groupby("age_group").survived.mean()
# Out:
# age_group
# adult     0.386189
# child     0.492754
# infant    0.772727
# senior    0.313673
# teen      0.476190
# Name: survived, dtype: float64

# %%
titanic.groupby(["age_group","sex"]).survived.mean()
# Out:
# age_group  sex
# adult      female    0.748201
#            male      0.186508
# child      female    0.515152
#            male      0.472222
# infant     female    0.888889
#            male      0.692308
# senior     female    0.698276
#            male      0.140078
# teen       female    0.833333
#            male      0.151515
# Name: survived, dtype: float64

# %%
titanic[["pclass","survived","age","fare"]].max()-titanic[["pclass","survived","age","fare"]].min()
# Out:
# pclass        2.0000
# survived      1.0000
# age          79.8333
# fare        512.3292
# dtype: float64

# %%
df = titanic[["pclass", "survived", "age", "fare"]]

def get_range(s):
    return s.max() - s.min()


df.apply(get_range)
# Out:
# pclass        2.0000
# survived      1.0000
# age          79.8333
# fare        512.3292
# dtype: float64

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
def z(a):
    if a==0:
        return "solo"
    elif a<5:
        return "average"
    else:
        return "large"

# %%
titanic["akgiu"]=titanic["sibsp"]+titanic["parch"]

# %%
titanic["akgiu"].apply(z)
# Out:
# 0          solo
# 1       average
# 2       average
# 3       average
# 4       average
#          ...
# 1304    average
# 1305    average
# 1306       solo
# 1307       solo
# 1308       solo
# Name: akgiu, Length: 1309, dtype: object
