# %%
import pandas as pd

# %%
carstocks=pd.read_csv("data/car_stocks.csv")

# %%
carstocks
# Out:
#    Symbol        Date        Open        High         Low       Close  \
# 0    RIVN  2021-11-10  106.750000  119.459999   95.199997  100.730003
# 1    RIVN  2021-11-11  114.625000  125.000000  108.010002  122.989998
# 2    RIVN  2021-11-12  128.645004  135.199997  125.250000  129.949997
# 3    RIVN  2021-11-15  130.800003  152.529999  127.510002  149.360001
# 4    RIVN  2021-11-16  163.800003  179.470001  153.779999  172.009995
# 5    RIVN  2021-11-17  160.880005  163.000000  140.350006  146.070007
# 6    RIVN  2021-11-18  136.809998  138.779999  120.150002  123.379997
# 7    RIVN  2021-11-19  129.979996  139.899994  125.599998  128.600006
# 8    RIVN  2021-11-22  123.879997  124.930000  106.910004  118.110001
# 9    RIVN  2021-11-23  117.830002  124.000000  113.000000  119.849998
# 10   RIVN  2021-11-24  119.379997  120.000000  113.449997  114.849998
# 11   RIVN  2021-11-26  111.000000  114.500000  106.139999  112.129997
# ...

# %%
carstocks["Open"].mean()
# Out:
# 79.46974371794872

# %%
carstocks[carstocks["Symbol"]=="RIVN"]["Close"].mean()
# Out:
# 127.52307653846154

# %%
carstocks.groupby("Symbol")["Close"].mean()
# Out:
# Symbol
# GM       62.164615
# LCID     49.829231
# RIVN    127.523077
# Name: Close, dtype: float64

# %%
titanic=pd.read_csv("data/titanic.csv")

# %%
titanic["age"]=titanic["age"].replace(["?"],[None]).astype("float")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# Float:숫자 데이터를 나누게 됨녀 나머지가 잇는 경우가 있다. 이런 
# 경우, 고국점 이하숫자로 표현해야 할필요가 잇는데 ,float 이라는 데
# 이터 타입으로 바꿔주면 소숫점 아래 4자리 가지를 기록할수있다

# %%
# Astype은 뒤에 오는 괄호 안에 오는 type으로 데이터 ㅇ타입을 바꿔달라는 코드

# %%
df=titanic[["pclass","survived","sex","age"]]

# %%
df
# Out:
#       pclass  survived     sex      age
# 0          1         1  female  29.0000
# 1          1         1    male   0.9167
# 2          1         0  female   2.0000
# 3          1         0    male  30.0000
# 4          1         0  female  25.0000
# ...      ...       ...     ...      ...
# 1304       3         0  female  14.5000
# 1305       3         0  female      NaN
# 1306       3         0    male  26.5000
# 1307       3         0    male  27.0000
# 1308       3         0    male  29.0000
#
# [1309 rows x 4 columns]

# %%
df.groupby("sex").mean()
# Out:
#           pclass  survived        age
# sex
# female  2.154506  0.727468  28.687071
# male    2.372479  0.190985  30.585233

# %%
df[df["survived"]==1]["age"].mean()
# Out:
# 28.918228103044495

# %%
df[df["sex"]=="male"].mean()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_9976\2359995525.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["sex"]=="male"].mean()
# pclass       2.372479
# survived     0.190985
# age         30.585233
# dtype: float64

# %%
gbo=df.groupby(by="sex")

# %%
gbo.get_group("male").mean()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_9976\1448670058.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   gbo.get_group("male").mean()
# pclass       2.372479
# survived     0.190985
# age         30.585233
# dtype: float64

# %%
gbo.get_group("male")
# Out:
#       pclass  survived   sex      age
# 1          1         1  male   0.9167
# 3          1         0  male  30.0000
# 5          1         1  male  48.0000
# 7          1         0  male  39.0000
# 9          1         0  male  71.0000
# ...      ...       ...   ...      ...
# 1302       3         0  male      NaN
# 1303       3         0  male      NaN
# 1306       3         0  male  26.5000
# 1307       3         0  male  27.0000
# 1308       3         0  male  29.0000
#
# [843 rows x 4 columns]

# %%
for i in gbo:
    print(i[0])
    print("----------")
    print(i[1])
# Out:
# female
# ----------
#       pclass  survived     sex   age
# 0          1         1  female  29.0
# 2          1         0  female   2.0
# 4          1         0  female  25.0
# 6          1         1  female  63.0
# 8          1         1  female  53.0
# ...      ...       ...     ...   ...
# 1286       3         1  female  38.0
# 1290       3         1  female  47.0
# 1300       3         1  female  15.0
# 1304       3         0  female  14.5
# 1305       3         0  female   NaN
#
# [466 rows x 4 columns]
# male
# ----------
#       pclass  survived   sex      age
# 1          1         1  male   0.9167
# 3          1         0  male  30.0000
# 5          1         1  male  48.0000
# 7          1         0  male  39.0000
# 9          1         0  male  71.0000
# ...      ...       ...   ...      ...
# 1302       3         0  male      NaN
# 1303       3         0  male      NaN
# 1306       3         0  male  26.5000
# 1307       3         0  male  27.0000
# ...

# %%
            
      @    
/ @ /   [_]| 
 |_|       |
 | |       |
/  /       | 
           |
           |
# Out:
#   Cell In[21], line 1
#     @
#          ^
# SyntaxError: invalid syntax

# %%
titanic.groupby("sex")["age"].mean()
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: age, dtype: float64

# %%
gbo["age"].mean()
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: age, dtype: float64

# %%
gbo["age"].max()
# Out:
# sex
# female    76.0
# male      80.0
# Name: age, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
gbo["age"].mean().plot(kind="bar")
plt.title("Average Age By Sex")
# Out:
# Text(0.5, 1.0, 'Average Age By Sex')

# %%
gbo=df.groupby(by="pclass")

# %%
gbo["age"].mean()
# Out:
# pclass
# 1    39.159918
# 2    29.506705
# 3    24.816367
# Name: age, dtype: float64

# %%
gbo=df.groupby(by="sex")
gbo["pclass"].mean()
# Out:
# sex
# female    2.154506
# male      2.372479
# Name: pclass, dtype: float64

# %%
stocks=pd.read_csv("data/car_stocks.csv")

# %%
stocks
# Out:
#    Symbol        Date        Open        High         Low       Close  \
# 0    RIVN  2021-11-10  106.750000  119.459999   95.199997  100.730003
# 1    RIVN  2021-11-11  114.625000  125.000000  108.010002  122.989998
# 2    RIVN  2021-11-12  128.645004  135.199997  125.250000  129.949997
# 3    RIVN  2021-11-15  130.800003  152.529999  127.510002  149.360001
# 4    RIVN  2021-11-16  163.800003  179.470001  153.779999  172.009995
# 5    RIVN  2021-11-17  160.880005  163.000000  140.350006  146.070007
# 6    RIVN  2021-11-18  136.809998  138.779999  120.150002  123.379997
# 7    RIVN  2021-11-19  129.979996  139.899994  125.599998  128.600006
# 8    RIVN  2021-11-22  123.879997  124.930000  106.910004  118.110001
# 9    RIVN  2021-11-23  117.830002  124.000000  113.000000  119.849998
# 10   RIVN  2021-11-24  119.379997  120.000000  113.449997  114.849998
# 11   RIVN  2021-11-26  111.000000  114.500000  106.139999  112.129997
# ...

# %%
gbo=stocks.groupby(by="Symbol")

# %%
gbo["High"].max()
# Out:
# Symbol
# GM       65.180000
# LCID     57.750000
# RIVN    179.470001
# Name: High, dtype: float64

# %%
gbo=df.groupby(by="sex")
gbo["age"].agg(["min","max"])
# Out:
#            min   max
# sex
# female  0.1667  76.0
# male    0.3333  80.0

# %%
gbo["age"].agg(["min","max","mean","median"])
# Out:
#            min   max       mean  median
# sex
# female  0.1667  76.0  28.687071    27.0
# male    0.3333  80.0  30.585233    28.0

# %%
gbo.agg({"age":["min","max"],"pclass":"mean"})
# Out:
#            age          pclass
#            min   max      mean
# sex
# female  0.1667  76.0  2.154506
# male    0.3333  80.0  2.372479

# %%
gbo=stocks.groupby(by="Symbol")
gbo.agg({"Open":"mean","Close":"mean","Volume":["mean","sum"]})
# Out:
#               Open       Close        Volume
#               mean        mean          mean         sum
# Symbol
# GM       61.937693   62.164615  2.025259e+07   263283700
# LCID     48.761538   49.829231  1.081098e+08  1405427200
# RIVN    127.710000  127.523077  5.252395e+07   682811400

# %%
def range(a):
    return a.max()-a.min()
a["age"].agg(["min","max",range])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 def range(a):
#       2     return a.max()-a.min()
# ----> 3 a["age"].agg(["min","max",range])
#
# NameError: name 'a' is not defined

# %%
a=titanic.groupby("pclass")
a["pclass"].count()
# Out:
# pclass
# 1    323
# 2    277
# 3    709
# Name: pclass, dtype: int64

# %%
titanic.groupby("pclass")["age"].count()
# Out:
# pclass
# 1    284
# 2    261
# 3    501
# Name: age, dtype: int64

# %%
def range(a):
    return a.max()-a.min()
titanic.groupby("pclass")["age"].agg(["min","max",range])
# Out:
#            min   max    range
# pclass
# 1       0.9167  80.0  79.0833
# 2       0.6667  70.0  69.3333
# 3       0.1667  74.0  73.8333

# %%
titanic["age"].size-titanic["age"].count()
#size:열의 글자와 숫자의 상관없이 크기(모두)를 세는 함수
# Out:
# 263

# %%
titanic.groupby("pclass")["age"].size()-titanic.groupby("pclass")["age"].count()
# Out:
# pclass
# 1     39
# 2     16
# 3    208
# Name: age, dtype: int64

# %%
def range(a):
    return a.size-a.count()
titanic.groupby("pclass")["age"].agg(range)
# Out:
# pclass
# 1     39
# 2     16
# 3    208
# Name: age, dtype: int64

# %%
titanic[titanic["pclass"]==1]["age"].size-titanic[titanic["pclass"]==1]["age"].count()
# Out:
# 39

# %%
carstocks.groupby("Symbol").agg({"Open":["min","max"],"Close":["min","max"]})
# Out:
#               Open                   Close
#                min         max         min         max
# Symbol
# GM       57.849998   64.330002   59.270000   64.610001
# LCID     42.299999   56.200001   40.750000   55.520000
# RIVN    106.750000  163.800003  100.730003  172.009995

# %%
carstocks.groupby("Symbol").agg({"Open":["min","max"],"Close":["min","max"]})
# Out:
#               Open                   Close
#                min         max         min         max
# Symbol
# GM       57.849998   64.330002   59.270000   64.610001
# LCID     42.299999   56.200001   40.750000   55.520000
# RIVN    106.750000  163.800003  100.730003  172.009995

# %%
carstocks.groupby("Symbol").agg(min_open=("Open","min"),max_open=("Open","max"),min_close=("Close","min"),max_close=("Close","max"))
# Out:
#           min_open    max_open   min_close   max_close
# Symbol
# GM       57.849998   64.330002   59.270000   64.610001
# LCID     42.299999   56.200001   40.750000   55.520000
# RIVN    106.750000  163.800003  100.730003  172.009995

# %%
titanic.groupby("sex")["age"].mean()
# Out:
# sex
# female    28.687071
# male      30.585233
# Name: age, dtype: float64

# %%
titanic.groupby(["sex","pclass","survived"])["age"].mean()
# Out:
# sex     pclass  survived
# female  1       0           35.200000
#                 1           37.109375
#         2       0           34.090909
#                 1           26.711051
#         3       0           23.418750
#                 1           20.814815
# male    1       0           43.658163
#                 1           36.168240
#         2       0           33.092593
#                 1           17.449274
#         3       0           26.679598
#                 1           22.436441
# Name: age, dtype: float64
