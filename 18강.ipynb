# %%
import pandas as pd

# %%
titanic=pd.read_csv("data/titanic.csv")

# %%
titanic["age"]=titanic["age"].replace(["?"],[None]).astype(float)
titanic["fare"]=titanic["fare"].replace(["?"],[None]).astype(float)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
# [1309 rows x 14 columns]

# %%
titanic.groupby(["pclass","sex"]).mean().index
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_2272\1489311410.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic.groupby(["pclass","sex"]).mean().index
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['pclass', 'sex'])

# %%
df.index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['pclass', 'sex'])

# %%
pops=pd.read_csv("data/state_pops.csv")

# %%
pops
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pops.set_index("state")
# Out:
#        year   population
# state
# AL     2012    4817528.0
# AL     2010    4785570.0
# AL     2011    4801627.0
# AL     2009    4757938.0
# AL     2013    4833722.0
# ...     ...          ...
# USA    2013  316128839.0
# USA    2009  306771529.0
# USA    2010  309326295.0
# USA    2011  311582564.0
# USA    2012  313873685.0
#
# [1272 rows x 2 columns]

# %%
pops.set_index(["state","year"])
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.set_index(["state","year"],inplace=True)
# inplace=True 는 데이터 원옵ㄴ을 인덱스가 적용되 형태호 고정시키는 효거거 있다.
# 그러나 inplace-True가 없으면 index를 적용하요 나온 내용이 한번 출력도기만 하고 
# 우너본 데이터에 영향을 주지느 못한다

# %%
pops.set_index(["state","year"]).sort_index()

# %%
pops.sort_index(inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

kor_s = [
    1427.22,
    1192.57,
    993.93,
    965.23,
    1130.65,
    1207.23,
    1310.46,
    1477.18,
    1220.04,
    948.05,
    1139.97,
    1267.64,
    1379.61,
    1643.80,
    1931.38,
    2061.07,
    2094.65,
    2449.08,
    2746.21,
    2913.36,
    3217.86,
    4246.11
]

us_s = [
    3783.67,
    2029.61,
    1539.73,
    1647.17,
    1986.53,
    2099.32,
    2263.41,
    2578.47,
    2161.68,
    1845.39,
    2349.89,
    2677.44,
    2965.74,
    3541.29,
    4375.10,
    4945.55,
    4987.79,
    6235.30,
    7425.96,
    7940.36,
    10201.51,
    14294.87
]

years = [2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(years,us_s,label="미국주가")
plt.plot(years,kor_s,label="한국주가")
plt.title("주가변동 선 그래프")
plt.xlabel("Year")
plt.legend()
plt.subplot(1,2,2)
plt.bar(years,us_s,label="미국주가")
plt.bar(years,kor_s,label="한국주가")
plt.title("주가변동 막대 그래프")
plt.xlabel("Year")
plt.legend()

# %%
pops.sort_index(level=1)
# Out:
#             population
# state year
# AK    1990    553290.0
# AL    1990   4050055.0
# AR    1990   2356586.0
# AZ    1990   3684097.0
# CA    1990  29959515.0
# ...                ...
# VT    2013    626630.0
# WA    2013   6971406.0
# WI    2013   5742713.0
# WV    2013   1854304.0
# WY    2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[1],ascending=[False])
# Out:
#              population
# state year
# AL    2013    4833722.0
# AK    2013     735132.0
# AZ    2013    6626624.0
# AR    2013    2959373.0
# CA    2013   38332521.0
# ...                 ...
# WV    1990    1792548.0
# WI    1990    4904562.0
# WY    1990     453690.0
# PR    1990          NaN
# USA   1990  249622814.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[0,1],ascending=[False,True])
# Out:
#             population
# state year
# WY    1990    453690.0
#       1991    459260.0
#       1992    466251.0
#       1993    473081.0
#       1994    480283.0
# ...                ...
# AK    2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[1])
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pops.sort_index(level=[0,1],ascending=[False,True])
# Out:
#             population
# state year
# WY    1990    453690.0
#       1991    459260.0
#       1992    466251.0
#       1993    473081.0
#       1994    480283.0
# ...                ...
# AK    2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0
#
# [1272 rows x 1 columns]

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.loc[["CA","AK"]]
# Out:
#             population
# state year
# CA    1990  29959515.0
#       1991  30470736.0
#       1992  30974659.0
#       1993  31274928.0
#       1994  31484435.0
#       1995  31696582.0
#       1996  32018834.0
#       1997  32486010.0
#       1998  32987675.0
#       1999  33499204.0
#       2000  33987977.0
#       2001  34479458.0
#       2002  34871843.0
#       2003  35253159.0
#       2004  35574576.0
#       2005  35827943.0
#       2006  36021202.0
#       2007  36250311.0
#       2008  36604337.0
#       2009  36961229.0
#       2010  37333601.0
#       2011  37668681.0
#       2012  37999878.0
#       2013  38332521.0
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0
#       1996    608569.0
#       1997    612968.0
#       1998    619933.0
#       1999    624779.0
#       2000    627963.0
#       2001    633714.0
#       2002    642337.0
#       2003    648414.0
#       2004    659286.0
#       2005    666946.0
#       2006    675302.0
#       2007    680300.0
#       2008    687455.0
#       2009    698895.0
#       2010    713868.0
#       2011    723375.0
#       2012    730307.0
#       2013    735132.0

# %%
pops.loc["NM":"TX"]
# Out:
# Empty DataFrame
# Columns: [state, year, population]
# Index: []

# %%
pops.loc['MT',1992]
# Out:
# population    825770.0
# Name: (MT, 1992), dtype: float64

# %%
pops.loc[["AK"]][2:6]
# Out:
#             population
# state year
# AK    1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0

# %%
pops.loc[("AK",1992):("AK",1995)]
# Out:
#             population
# state year
# AK    1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0

# %%
pops.loc[("AK",2011):("AL",1993)]
# Out:
#             population
# state year
# AK    2011    723375.0
#       2012    730307.0
#       2013    735132.0
# AL    1990   4050055.0
#       1991   4099156.0
#       1992   4154014.0
#       1993   4214202.0

# %%
titanic=pd.read_csv("data/titanic.csv")

# %%
titanic.loc[19]["name"]
# Out:
# 'Beattie, Mr. Thomson'

# %%
pops=pd.read_csv("data/state_pops.csv").replace([" "],[None])

# %%
pops.set_index(["year","state"],inplace=True)

# %%
pops.loc[1990]
# Out:
#         population
# state
# AL       4050055.0
# AK        553290.0
# AZ       3684097.0
# AR       2356586.0
# CA      29959515.0
# CO       3307618.0
# CT       3291967.0
# DE        669567.0
# DC        605321.0
# FL      13033307.0
# GA       6512602.0
# HI       1113491.0
# ID       1012384.0
# IL      11453316.0
# IN       5557798.0
# IA       2781018.0
# KS       2481349.0
# KY       3694048.0
# LA       4221532.0
# ME       1231719.0
# MD       4799770.0
# MA       6022639.0
# MI       9311319.0
# MN       4389857.0
# MS       2578897.0
# MO       5128880.0
# MT        800204.0
# NE       1581660.0
# NV       1220695.0
# NH       1112384.0
# NJ       7762963.0
# NM       1521574.0
# NY      18020784.0
# NC       6664016.0
# ND        637685.0
# OH      10864162.0
# OK       3148825.0
# OR       2860375.0
# PA      11903299.0
# RI       1005995.0
# SC       3501155.0
# SD        697101.0
# TN       4894492.0
# TX      17056755.0
# UT       1731223.0
# VT        564798.0
# VA       6216884.0
# WA       4903043.0
# WV       1792548.0
# WI       4904562.0
# WY        453690.0
# PR             NaN
# USA    249622814.0

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index()
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
# Out:
#         population
# state
# AL       4050055.0
# AK        553290.0
# AZ       3684097.0
# AR       2356586.0
# CA      29959515.0
# CO       3307618.0
# CT       3291967.0
# DE        669567.0
# DC        605321.0
# FL      13033307.0
# GA       6512602.0
# HI       1113491.0
# ID       1012384.0
# IL      11453316.0
# IN       5557798.0
# IA       2781018.0
# KS       2481349.0
# KY       3694048.0
# LA       4221532.0
# ME       1231719.0
# MD       4799770.0
# MA       6022639.0
# MI       9311319.0
# MN       4389857.0
# MS       2578897.0
# MO       5128880.0
# MT        800204.0
# NE       1581660.0
# NV       1220695.0
# NH       1112384.0
# NJ       7762963.0
# NM       1521574.0
# NY      18020784.0
# NC       6664016.0
# ND        637685.0
# OH      10864162.0
# OK       3148825.0
# OR       2860375.0
# PA      11903299.0
# RI       1005995.0
# SC       3501155.0
# SD        697101.0
# TN       4894492.0
# TX      17056755.0
# UT       1731223.0
# VT        564798.0
# VA       6216884.0
# WA       4903043.0
# WV       1792548.0
# WI       4904562.0
# WY        453690.0
# PR             NaN
# USA    249622814.0

# %%
pops.loc[1].sort_index()
# Out:
# population    4785570.0
# state                AL
# year               2010
# Name: 1, dtype: object

# %%
pops=pd.read_csv("data/state_pops.csv")

# %%
pops.set_index(["state","year"],inplace=True)

# %%
pops.sort_index(inplace=True)

# %%
pops.loc[:, 1990, :]
# Out:
#         population
# state
# AK        553290.0
# AL       4050055.0
# AR       2356586.0
# AZ       3684097.0
# CA      29959515.0
# CO       3307618.0
# CT       3291967.0
# DC        605321.0
# DE        669567.0
# FL      13033307.0
# GA       6512602.0
# HI       1113491.0
# IA       2781018.0
# ID       1012384.0
# IL      11453316.0
# IN       5557798.0
# KS       2481349.0
# KY       3694048.0
# LA       4221532.0
# MA       6022639.0
# MD       4799770.0
# ME       1231719.0
# MI       9311319.0
# MN       4389857.0
# MO       5128880.0
# MS       2578897.0
# MT        800204.0
# NC       6664016.0
# ND        637685.0
# NE       1581660.0
# NH       1112384.0
# NJ       7762963.0
# NM       1521574.0
# NV       1220695.0
# NY      18020784.0
# OH      10864162.0
# OK       3148825.0
# OR       2860375.0
# PA      11903299.0
# PR             NaN
# RI       1005995.0
# SC       3501155.0
# SD        697101.0
# TN       4894492.0
# TX      17056755.0
# USA    249622814.0
# UT       1731223.0
# VA       6216884.0
# VT        564798.0
# WA       4903043.0
# WI       4904562.0
# WV       1792548.0
# WY        453690.0

# %%
pops.loc[:,1990:1991,:]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
# AL    1990   4050055.0
#       1991   4099156.0
# AR    1990   2356586.0
# ...                ...
# WI    1991   4964343.0
# WV    1990   1792548.0
#       1991   1798735.0
# WY    1990    453690.0
#       1991    459260.0
#
# [106 rows x 1 columns]

# %%
pops.loc[:,[2013],:]
# Out:
#              population
# state year
# AK    2013     735132.0
# AL    2013    4833722.0
# AR    2013    2959373.0
# AZ    2013    6626624.0
# CA    2013   38332521.0
# CO    2013    5268367.0
# CT    2013    3596080.0
# DC    2013     646449.0
# DE    2013     925749.0
# FL    2013   19552860.0
# GA    2013    9992167.0
# HI    2013    1404054.0
# IA    2013    3090416.0
# ID    2013    1612136.0
# IL    2013   12882135.0
# IN    2013    6570902.0
# KS    2013    2893957.0
# KY    2013    4395295.0
# LA    2013    4625470.0
# MA    2013    6692824.0
# MD    2013    5928814.0
# ME    2013    1328302.0
# MI    2013    9895622.0
# MN    2013    5420380.0
# MO    2013    6044171.0
# MS    2013    2991207.0
# MT    2013    1015165.0
# NC    2013    9848060.0
# ND    2013     723393.0
# NE    2013    1868516.0
# NH    2013    1323459.0
# NJ    2013    8899339.0
# NM    2013    2085287.0
# NV    2013    2790136.0
# NY    2013   19651127.0
# OH    2013   11570808.0
# OK    2013    3850568.0
# OR    2013    3930065.0
# PA    2013   12773801.0
# PR    2013    3615086.0
# RI    2013    1051511.0
# SC    2013    4774839.0
# SD    2013     844877.0
# TN    2013    6495978.0
# TX    2013   26448193.0
# USA   2013  316128839.0
# UT    2013    2900872.0
# VA    2013    8260405.0
# VT    2013     626630.0
# WA    2013    6971406.0
# WI    2013    5742713.0
# WV    2013    1854304.0
# WY    2013     582658.0

# %%
pops[pops["population"]%2==0]
# Out:
#             population
# state year
# AK    1990    553290.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
#       1995    604412.0
# ...                ...
# WY    2004    509106.0
#       2007    534876.0
#       2010    564222.0
#       2012    576626.0
#       2013    582658.0
#
# [645 rows x 1 columns]

# %%
a=titanic.groupby(by="sex")

# %%
a.agg({"age":["min","max","mean"],"fare":["min","max","mean"],"survived":"mean"})
# Out:
#            age                   fare                       survived
#            min   max       mean   min       max       mean      mean
# sex
# female  0.1667  76.0  28.687071  6.75  512.3292  46.198097  0.727468
# male    0.3333  80.0  30.585233  0.00  512.3292  26.154601  0.190985

# %%
titanic.groupby(["pclass","sex"])["age"].mean().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='pclass,sex'>

# %%
titanic.groupby(["pclass","sex"])["age"].mean().unstack()
# Out:
# sex        female       male
# pclass
# 1       37.037594  41.029250
# 2       27.499191  30.815401
# 3       22.185307  25.962273

# %%
titanic.groupby(["pclass","sex"])["age"].mean().unstack().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='pclass'>

# %%
titanic.groupby(["sex","pclass"])["age"].mean().unstack().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='sex'>

# %%
titanic.groupby(["sex","survived"])["age"].mean()

# %%
titanic.groupby(["sex","survived"])["age"].mean().unstack().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='sex'>

# %%
df=titanic.groupby(["sex","survived"])["age"].mean()

# %%
df.unstack().rename(columns={0:"Died",1:"survived"}).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='sex'>
