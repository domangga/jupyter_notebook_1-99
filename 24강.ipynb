# %%
import pandas as pd

# %%
from wordcloud import WordCloud
from string import digits
import re

# %%
text=""
with open("data/대화.txt","r",encoding="utf-8")as f:
    lines=f.readlines()
for line in lines:
    text+= line.replace("어","").replace("응","").replace("사진\n","").replace("ㅋ","").replace("삭제된 메시지입니다.\n","").replace("ㅎ","").replace("준원","").replace("양민석","").replace("오후","").replace("준형","")
    text = re.sub(r'[0-9]+', '', text)
print(text)
# Out:
# () 학년 반😆 님과 카카오톡 대화
# 저장한 날짜 : -- ::
#
# --------------- 년 월 일 화요일 ---------------
# [] [오전 :] 체육복 챙겨 애들아
# [] [오전 :] 얘들아 까먹었으면 집 다시 갔다와~
# [] [오전 :] 오늘 화요일
# [정연택] [오전 :] [] [ :] 선생님 교시 수업 레프리 조금 늦을 거 습니다 체육 선생님이 양해 부탁드렸습니다
# [정연택] [ :]  민석아 천천히오렴
# [정연택] [ :] [정연택] [ :] [] [ :] @
# [] [ :] 아
# [] [ :] 디냐
# [] [ :] 피시방
# [] [ :] 간다
# [] [ :] 점롸
# [] [ :] 모란
# [] [ :] 전화걸
# [] [ :]
# [] [ :] 같이가
# [] [ :] 나랑같이가
# [] [ :] 나
# --------------- 년 월 일 수요일 ---------------
# [] [오전 :] [] [오전 :] 국 수행>_<
# [] [오전 :] https://youtu.be/-TXfVaEwXg
# [] [오전 :] 성일정보고 학생여러분 안녕하세요。내년에 보다 나은 철쭉학술제를 준비하기 위해 설문을 받고합니다。수업등 학업을 병행하면서 학생들이 준비한 행사이다보니 부족한 점이 많은 것도 사실이나 내년에 보다 나은 우리들의 축제를 위해  원하는 마음으로 작성하여 주시기 바랍니다.
#
# ＊６월 １일  ５시에 열리는 학생회 피드백회의에 자료로 활용되며 내일 ３시까지 입력해주세요
# [] [오전 :] https://forms.gle/zEzkVmWdWBFA
# [정연택] [오전 :] [시정표 변경 관련]
# /(목):성일고(전학년) 모의고사로 인한 시정표 변경이 있습니다.
# 남고 전학년 모의고사날에는 중식 지연으로 인해 교시 이후 시간표 분씩 단축됩니다.
# ...
# 아침맞이 : :~:
# 교시 : :~:(분)
# 교시 : :~:(분)
# 교시 : :~:(분)
# 교시 : :~:(분)
# 중식 : :~:(분)
# ...

# %%
font_path = 'C:/Windows/Fonts/malgun.ttf'
wc = WordCloud(font_path=font_path, background_color="white", width=600, height=400)
wc.generate(text)
wc.to_file("a.png")

# %%
import matplotlib.pyplot as plt
from string import digits
from PIL import Image
import numpy as np

font_path = 'C:/Windows/Fonts/malgun.ttf'
wc = WordCloud(font_path=font_path, background_color="white", width=600, height=400)
wc.generate(text)
wc.to_file("result_review.png")
plt.imshow(wc)
plt.title("Word Frequency", size = 13)
plt.axis('off')
plt.show()

# %%
im=Image.open('d.png')
mask_arr = np.array(im) 


wc = WordCloud(font_path=font_path, background_color="yellow", mask = mask_arr, prefer_horizontal = True, width=600, height=400)
wc.generate(text)
wc.to_file("result_review.png")
plt.imshow(wc)
plt.title("Word Frequency", size = 13)
plt.axis('off')
plt.show()

# %%
nba=pd.read_csv("data/nba.csv")

# %%
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba["Weight in Killograms"]=nba["Weight"]/2.20462

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary  Weight in Killograms
# 0              Texas  7730337.0             81.646724
# 1          Marquette  6796117.0            106.594334
# 2  Boston University        NaN             92.986546

# %%
nba["Salary in Millions"]=nba["Salary"]*0.000001

# %%
nba.dropna().tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 442   Trevor Booker  Utah Jazz    33.0       PF  28.0    6-8   228.0
# 443      Trey Burke  Utah Jazz     3.0       PG  23.0    6-1   191.0
# 444      Alec Burks  Utah Jazz    10.0       SG  24.0    6-6   214.0
# 446  Derrick Favors  Utah Jazz    15.0       PF  24.0   6-10   265.0
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
#
#           College      Salary  Weight in Killograms  Salary in Millions
# 442       Clemson   4775000.0            103.419183            4.775000
# ...

# %%
nba.replace({None},{0})
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457              0               0     NaN        0   NaN      0     NaN
#
#                College     Salary  Weight in Killograms  Salary in Millions
# ...

# %%
nba['Salary'] = nba["Salary"].fillna(0)

# %%
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary  Weight in Killograms  Salary in Millions
# 0              Texas   7730337.0             81.646724            7.730337
# ...

# %%
nba["College"]=nba["College"].replace({None},{"None"})

# %%
nba.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary  Weight in Killograms  Salary in Millions
# 0              Texas   7730337.0             81.646724            7.730337
# ...

# %%
nba["College"].fillna("None",inplace=True)

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Weight in Killograms  Salary in Millions
# ...

# %%
nba=pd.read_csv("data/nba.csv")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba["Salary"].fillna(0,inplace=True)
nba["College"].fillna("None",inplace=True)
nba.dropna(how="all",inplace=True)

# %%
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# 4               None   5000000.0
# 5               None  12000000.0

# %%
nba.tail(6)
# Out:
#               Name       Team  Number Position   Age Height  Weight   College  \
# 451  Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0    Dayton
# 452     Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453   Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454      Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0      None
# 455   Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0      None
# 456    Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(how="any")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba["Salary"]=nba["Salary"].astype("int")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College   Salary
# 0                Texas  7730337
# ...

# %%
nba["Age"]=nba["Age"].astype("int")
nba["Number"]=nba["Number"].astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba=pd.read_csv("data/nba.csv")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.fillna(0,inplace=True)

# %%
nba["Salary"]=nba["Salary"].astype("int")

# %%
nba.sort_values(["Salary"],ascending=False).head(10)
# Out:
#                   Name                   Team  Number Position   Age Height  \
# 109        Kobe Bryant     Los Angeles Lakers    24.0       SF  37.0    6-6
# 169       LeBron James    Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33     Carmelo Anthony        New York Knicks     7.0       SF  32.0    6-8
# 251      Dwight Howard        Houston Rockets    12.0        C  30.0   6-11
# 339         Chris Bosh             Miami Heat     1.0       PF  32.0   6-11
# 100         Chris Paul   Los Angeles Clippers     3.0       PG  31.0    6-0
# 414       Kevin Durant  Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164       Derrick Rose          Chicago Bulls     1.0       PG  27.0    6-3
# 349        Dwyane Wade             Miami Heat     3.0       SG  34.0    6-4
# 294  LaMarcus Aldridge      San Antonio Spurs    12.0       PF  30.0   6-11
#
#      Weight       College      Salary
# 109   212.0           NaN  25000000.0
# 169   250.0           NaN  22970500.0
# ...

# %%
nba.sort_values(["Salary"],ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %%
nba.sort_values("Salary",ascending=False, na_position = "first" ).tail()
# Out:
#                        Name                  Team  Number Position   Age  \
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
#
#     Height  Weight           College    Salary
# 175    6-5   179.0         Tennessee  111196.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 32     6-7   205.0               NaN   30888.0

# %%
nba=pd.read_csv("data/nba.csv").dropna(how ="all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype("int")
